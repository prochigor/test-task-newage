# %% [markdown]
# # Level 3 Data parsing from OLX nedvizhimost and writing to google sheet

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

from dataclasses import dataclass, fields
from urllib.parse import urljoin

BASE_URL = "https://www.olx.ua/uk/nedvizhimost/"

# %% [markdown]
# # Model for estate parsing

# %%
@dataclass
class Estate:
    title: str
    price: str
    floor: int
    storey: int
    locality: str
    area: int | float


PRODUCT_FIELDS = [field.name for field in fields(Estate)]

# %% [markdown]
# # getting links to all estates

# %%
def get_links_on_page(driver: webdriver) -> list:
    elements = driver.find_elements(By.CLASS_NAME, "css-rc5s2u")
    return [element.get_attribute("href") for element in elements]


def get_estate_links() -> list:
    links = []
    with webdriver.Chrome() as driver:
        driver.get(BASE_URL)
        pages_count = int(driver.find_elements(By.CLASS_NAME, "pagination-item")[-1].text)
        links.extend(get_links_on_page(driver))
        for page in range(2, pages_count + 1):
            driver.get(urljoin(BASE_URL, f"?page={page}"))
            links.extend(get_links_on_page(driver))
    return links


estate_detail_links = get_estate_links()

# %% [markdown]
# # function for pursing single estate

# %%
def get_block_element(estate: webdriver, word: str, count_word: int) -> str:
    elements = estate.find_elements(
        By.XPATH,
        f'//li[@class="css-1r0si1e" and starts-with(p, "{word}")]'
    )

    if elements:
        element = elements[0].text.split(" ")[count_word]
    else:
        element = "?"

    return element


def parse_single_estate(estate: webdriver) -> Estate:
    floor = get_block_element(estate, "Поверх:", 1)
    storey = get_block_element(estate, "Поверховість:", 1)
    area = get_block_element(estate, "Загальна площа:", 2)

    return Estate(
        title=estate.find_element(By.CLASS_NAME, "css-1juynto").text,
        price=estate.find_element(By.CLASS_NAME, "css-12vqlj3").text,
        floor=floor,
        storey=storey,
        locality=estate.find_element(By.CLASS_NAME, "css-1cju8pu").text,
        area=area
    )

# %% [markdown]
# # getting all estates

# %%
from selenium.common import NoSuchElementException


def get_estates() -> [Estate]:
    all_estates = []
    with webdriver.Chrome() as driver:
        for link in estate_detail_links[:50]:
            try:
                driver.get(link)
                all_estates.append(parse_single_estate(driver))
            except NoSuchElementException:
                print(f"Link {link} is not available")

    return all_estates


estates = get_estates()
estates
# Out:
# Link https://www.olx.ua/d/uk/obyavlenie/2-h-kmnatna-kvartira-IDSkw1A.html is not available
# [Estate(title='Оренда будинку 230кв.м.12сот, р-н Сирець, поруч ЖК Сирецькі Сади', price='1 500 $', floor='?', storey='4', locality='Київ, Подільський', area='233'),
#  Estate(title='Квартира с новым ремонтом - Площадь Конституции', price='450 грн.', floor='3', storey='?', locality='Харків, Київський', area='30'),
#  Estate(title='Лучший хостел Киева . Посуточно , понедельно , помесячно . Долгосрочно', price='60 грн.', floor='?', storey='?', locality='Київ, Святошинський', area='?'),
#  Estate(title='Продам 3к квартира на пр. Гагарина Соборный район', price='43 000 $', floor='5', storey='5', locality='Дніпро, Соборний', area='57'),
#  Estate(title='Сдам дом, дачу на длительный срок.', price='14 000 грн.', floor='?', storey='2', locality='Київ, Дарницький', area='80'),
#  Estate(title='Дача для переселенцев', price='100 $', floor='?', storey='2', locality='Суми,', area='50'),
#  Estate(title='Сдам 2-х уровневую студию на Одесской', price='5 500 грн.', floor='4', storey='4', locality='Харків, Слобідський', area='36'),
#  Estate(title='Оренда приміщеннь під комерційну діяльність', price='100 грн.', floor='2', storey='2', locality='Фастів,', area='90'),
#  Estate(title='Сдам 1 ком. квартиру в Аркадийском дворце', price='8 000 грн.', floor='2', storey='12', locality='Одеса, Приморський', area='50'),
#  Estate(title='ВЛАСНИК! Сдаю 2х комн.квартиру посуточно. Центр. Свежий ремонт.', price='1 100 грн.', floor='2', storey='?', locality='Краматорськ,', area='50'),
#  Estate(title='Люкс апартаменти в центрі ЖК Театральний.МОЖЛИВА ЗДАЧА ПОГОДИННО', price='500 грн.', floor='3', storey='?', locality='Рівне,', area='44'),
#  Estate(title='Сдам в аренду помещение на ул. Передовой 28м2', price='17 500 грн.', floor='1', storey='1', locality='Дніпро, Амур-Нижньодніпровський', area='28'),
#  Estate(title='1-2 ком кв Посуточно Солнечная Набережна Слобожанс Игрень Центр Вокзал', price='750 грн.', floor='1', storey='?', locality='Дніпро, Амур-Нижньодніпровський', area='54'),
#  Estate(title='Посуточно апартаменты студио. м. Славутич - 10 мин., Осокорки', price='500 грн.', floor='3', storey='?', locality='Київ, Дарницький', area='16'),
#  Estate(title='2х кімн.кв (інд. опалення))! Р-н Водоканал! Від власника!', price='10 000 грн.', floor='9', storey='10', locality='Кременчук,', area='79'),
#  Estate(title='Сдам посуточно 1 комн.кв . Район МРЭО, дет ,поликлиники.', price='1 000 грн.', floor='3', storey='?', locality='Краматорськ,', area='41'),
#  Estate(title='Хостел недорого, Койко - место, посуточно', price='170 грн.', floor='?', storey='?', locality='Дніпро, Центральний', area='?'),
#  Estate(title='Затишна квартира в центрі, ближче до Софіївського парку.', price='600 грн.', floor='1', storey='?', locality='Умань,', area='38'),
#  Estate(title='Без % 1к Виноградарь Вітряні гори Межевий провулок 5а', price='31 500 $', floor='4', storey='9', locality='Київ, Подільський', area='30.30'),
#  Estate(title='Продаж офісу в IQ центрі .Можлива розстрочка платежу на 2 місяці.', price='45 630 $', floor='2', storey='6', locality='Хмельницький,', area='35.10'),
#  Estate(title='13 фонтана ресторан Риф Рыба Прямой вид моря Калипсо 9 этаж', price='100 000 $', floor='9', storey='10', locality='Одеса, Київський', area='55'),
#  Estate(title='Продаж 3 кім. квартири в центрі Яготина поряд з озером. 81 кв.м.', price='29 000 $', floor='1', storey='1', locality='Яготин,', area='81'),
#  Estate(title='Продаю 3комнатную на Интернате', price='12 500 $', floor='2', storey='5', locality='Кривий Ріг, Тернівський', area='57'),
#  Estate(title='Продам шикарную 3-к квартиру', price='121 000 $', floor='1', storey='9', locality='Харків, Індустріальний', area='80'),
#  Estate(title='Продаж будинку вул Голубина', price='62 800 $', floor='?', storey='1', locality='Рівне,', area='90'),
#  Estate(title='Котедж в Карпатах, прибуткова нерухомість', price='177 500 $', floor='?', storey='1', locality='Красник,', area='71'),
#  Estate(title='ЗДАМ приміщення 13 м. ПІОНЕР, Січеславська (Кремлівська) 3, 6000 грн', price='6 000 грн.', floor='1', storey='4', locality='Кривий Ріг, Покровський', area='13'),
#  Estate(title='Продаж квартири "Гостьового типу" 22 м2', price='22 000 $', floor='1', storey='5', locality='Щасливе,', area='22'),
#  Estate(title='Терміновий продаж! 3-к кв. в новобудові, Дешевше ніж у забудовника', price='69 000 $', floor='11', storey='17', locality='Черкаси,', area='106.48'),
#  Estate(title='Сдам 1-к квартиру Центр', price='3 000 грн.', floor='4', storey='5', locality='Суми,', area='36'),
#  Estate(title='Оренда 2-х кімнатної, метро "Почайна", "Оболонь", вул. Йорданська 9Д', price='13 000 грн.', floor='3', storey='9', locality='Київ, Оболонський', area='52'),
#  Estate(title='Продам незавершений 2-о поверховий будинок 255 кВ.м. в с. Рудно', price='125 000 $', floor='?', storey='2', locality='Рудно,', area='255'),
#  Estate(title='ВІЛЬНА! ЖК Варшавський, пр Правди 45а! В будинку не має ремонтів', price='19 800 грн.', floor='23', storey='25', locality='Київ, Подільський', area='48'),
#  Estate(title='Сдам кв.Л.Б.4мик. 2к.АО газ.10/10 крыша ремонт,МПО,2лоджии, мебель, т', price='7 000 грн.', floor='10', storey='10', locality="Кам'янське,", area='50'),
#  Estate(title='Продам 2к 60м2 Софія, автономне газове, ліфт', price='50 000 $', floor='4', storey='5', locality='Вінниця, Ленінський', area='60'),
#  Estate(title='Макаренка 1 а, нежитлове євроремонт, офіс, фасад, 68кв.м, 80000у.е', price='80 000 $', floor='1', storey='2', locality='Київ, Дніпровський', area='68'),
#  Estate(title='№471.Продам рівну ділянку зі світлом в селі Гнідин, вулиця Щаслива.', price='24 000 $', floor='?', storey='?', locality='Гнідин,', area='?'),
#  Estate(title='ПРОДАМ або ЗДАМ в оренду комплекс будівель', price='10 $', floor='?', storey='?', locality='Вознесенськ,', area='1'),
#  Estate(title='Канатная/Арнаутская фасад , цоколь.', price='20 000 $', floor='1', storey='3', locality='Одеса, Приморський', area='26'),
#  Estate(title='Посуточно квартира в центре ул. Старокозацкая, военный госпиталь', price='1 000 грн.', floor='8', storey='?', locality='Дніпро, Центральний', area='45'),
#  Estate(title='Будинок 72,6м2, одноповерховий котедж', price='47 190 $', floor='?', storey='1', locality='Київ, Дарницький', area='72.60'),
#  Estate(title='Продам житловий, теплий будинок в Мирному 35000$', price='35 000 $', floor='?', storey='1', locality='Дніпро, Чечеловский', area='59'),
#  Estate(title='171 м2 для большой семьи в центре Днепра в р-не Меноры. Паркинг.', price='1 400 $', floor='18', storey='24', locality='Дніпро, Центральний', area='171'),
#  Estate(title='№0108.Сучасний будинок в с. Гнідин.', price='140 000 $', floor='?', storey='2', locality='Гнідин,', area='124'),
#  Estate(title='Гончара 51, Нежитлове, Золоті ворота, 73,5 кв.м, 189000у.е', price='187 000 $', floor='1', storey='10', locality='Київ, Шевченківський', area='74'),
#  Estate(title='Земельна ділянка 2,0396га в Михайлівці- Рубежівці,Київська область', price='388 000 $', floor='?', storey='?', locality='Михайлівка-Рубежівка,', area='?'),
#  Estate(title='Продам частину будинку в цетрі під комерцію', price='36 000 $', floor='?', storey='1', locality="Кам'янець-Подільський,", area='29.90'),
#  Estate(title='Продажа Дом Стоянка Дисконт 175 М2 4 комн КГ "White Stones" 14 соток', price='410 000 $', floor='?', storey='1', locality='Стоянка,', area='175'),
#  Estate(title="Продаж таунхаус 105м2 3км від Киева, Погреби, Троєщина, Зазим'я", price='74 000 $', floor='?', storey='2', locality='Погреби,', area='105')]

# %% [markdown]
# # Implemented get links with beautiful soup, because it faster

# %%
import requests
from bs4 import BeautifulSoup


def soup_get_links_and_locations_on_page(soup: BeautifulSoup) -> list:
    return [
        (element["href"], element.select_one(".css-1a4brun").text.split(" -")[0]) 
        for element in soup.select(".css-rc5s2u")
    ]


def soup_get_estate_links() -> list:
    links_and_locs = []
    page = requests.get(BASE_URL).content
    soup = BeautifulSoup(page, "html.parser")
    pages_count = int(soup.select(".pagination-item")[-1].text)
    links_and_locs.extend(soup_get_links_and_locations_on_page(soup))
    for page in range(2, pages_count + 1):
        page = requests.get(urljoin(BASE_URL, f"?page={page}")).content
        soup = BeautifulSoup(page, "html.parser")
        links_and_locs.extend(soup_get_links_and_locations_on_page(soup))

    return links_and_locs

soup_estate_detail = soup_get_estate_links()

# %% [markdown]
# # get info with beautifulsoup for fast works

# %%
def soup_get_block_element(estate: BeautifulSoup, word: str, count_word: int) -> str:
    elements = estate.select(
        f'.css-1r0si1e > p:contains("{word}")'
    )

    if elements:
        element = elements[0].text.split(" ")[count_word]
    else:
        element = "?"

    return element


def soup_parse_single_estate(estate: BeautifulSoup, location: str) -> Estate:
    floor = soup_get_block_element(estate, "Поверх:", 1)
    storey = soup_get_block_element(estate, "Поверховість:", 1)
    area = soup_get_block_element(estate, "Загальна площа:", 2)

    return Estate(
        title=estate.select_one(".css-1juynto").text,
        price=estate.select_one(".css-12vqlj3").text,
        floor=floor,
        storey=storey,
        locality=location,
        area=area
    )


def soup_get_estates(soup_estates: list) -> [Estate]:
    all_estates = []
    for element in soup_estates:
        try:
            page = requests.get(urljoin(BASE_URL, element[0])).content
            soup = BeautifulSoup(page, "html.parser")
            location = element[1]
            all_estates.append(soup_parse_single_estate(soup, location))
        except AttributeError:
            print(f"Link https://www.olx.ua/{element[0]} is not available")

    return all_estates


soup_estates_info = soup_get_estates(soup_estate_detail)
soup_estates_info
# Out:
# Link /d/uk/obyavlenie/odnokmnatna-kvartira-rpn-dk-sinergya-IDUmlmc.html is not available
# Link /d/uk/obyavlenie/odnokmnatna-kvartira-rpn-dk-sinergya-IDUmlmc.html is not available
# Link /d/uk/obyavlenie/dom-350-kv-m-romankov-rayon-solnechnaya-dolina-uchastok-25-sotok-IDLRZ56.html is not available
# [Estate(title='Сдам квартиру м. Ботанический сад ул. Авиахимическая, 7', price='3 700 грн.', floor='3', storey='8', locality='Харків, Шевченківський ', area='20'),
#  Estate(title='Посуточно квартира  Таирово, Левитана, пр-к Небесной Сотни, ТРЦ Сити-ц', price='750 грн.', floor='14', storey='?', locality='Одеса, Київський', area='45'),
#  Estate(title='Продается ділянка 5 сот. 10 км від Киева. 800м. Сільпо', price='16 500 $', floor='?', storey='?', locality='Білогородка', area='?'),
#  Estate(title='Реально є! Оренда 1 к. видової квартири на березі Дніпра', price='9 000 грн.', floor='7', storey='16', locality='Черкаси', area='37'),
#  Estate(title='Продаємо офіс в центрі Києва', price='105 000 $', floor='1', storey='3', locality='Київ, Голосіївський', area='45'),
#  Estate(title='Хостел правый берег Киев! Комната на 4 человека!', price='170 грн.', floor='?', storey='?', locality='Київ, Печерський', area='?'),
#  Estate(title='Оренда трикімнатної квартири. Локація Фединця .', price='10 000 грн.', floor='3', storey='5', locality='Ужгород', area='65'),
#  Estate(title='47 м2 2 квартира з паркомісцем Євроремонт Заїхав та живи! Власник БЕЗ%', price='45 990 $', floor='2', storey='2', locality='Боярка', area='46'),
#  Estate(title='2-к квартира 56,65 м2 в ЖК Молодість по програмі єОселя від забудовн.!', price='47 628 $', floor='2', storey='5', locality='Ірпінь', area='56.65'),
#  Estate(title='ЦЕНТР, Б.Арнаутская,2. Рядом ЖД, военный Госпиталь ОЧЕНЬ ТЕПЛАЯ. Хоз', price='450 грн.', floor='3', storey='?', locality='Одеса, Приморський', area='30'),
#  Estate(title='квартира 2-кімн. вул. Каштанова 5, метро Почайна/Лівобережна 20 хв', price='6 800 грн.', floor='8', storey='9', locality='Київ, Деснянський', area='50'),
#  Estate(title='Новинка! Однокімнатна повноцінна квартира . Льонокомбінат', price='28 000 $', floor='7', storey='9', locality='Рівне', area='34'),
#  Estate(title='Унікальна локація для життя! 2 квартира 67 м2 з двориком та ремонтом', price='67 990 $', floor='2', storey='2', locality='Тарасівка', area='68'),
#  Estate(title='Продаж 1 кімнатної квартири', price='17 800 $', floor='4', storey='4', locality='Стрий', area='33'),
#  Estate(title='Продам 3к квартиру з індивід. опал.', price='37 000 $', floor='6', storey='6', locality="Кам'янець-Подільський", area='65'),
#  Estate(title='Продається 1 кімнатна квартира під ремонт ЖК Благород, с. Крюковщіна', price='32 500 $', floor='6', storey='10', locality='Крюківщина', area='33.50'),
#  Estate(title='Оренда офісу в центрі на вул. Січових Стрільців', price='15 000 грн.', floor='1', storey='3', locality='Львів, Галицький', area='45'),
#  Estate(title='продаж кімнати  р-н "Осташівка"', price='10 000 $', floor='2', storey='5', locality='Умань', area='18'),
#  Estate(title='Сдам двухкомнатную квартиру шолом алейхема , хозяин м. Лесная', price='8 000 грн.', floor='5', storey='9', locality='Київ, Деснянський', area='52'),
#  Estate(title='Сдам посуточно квартиру пр.Шевченкоул.Довженко/институт Филатова', price='800 грн.', floor='4', storey='?', locality='Одеса, Приморський', area='45'),
#  Estate(title='Квартира почасово посуточно 1 комн. на пр.Богдана Хмельницкого', price='500 грн.', floor='4', storey='?', locality='Дніпро, Шевченківський', area='30'),
#  Estate(title='Продам дом, жилая улица, коммуникации, Семиполки, Е відновлення', price='40 000 $', floor='?', storey='2', locality='Семиполки', area='55.90'),
#  Estate(title='Продам дом  в  Дачном !', price='27 500 $', floor='?', storey='1', locality='Дачне', area='80'),
#  Estate(title='Продажа 1 комн кв Хортицкий район/ 40 м кв.,два балкона', price='17 499 $', floor='9', storey='9', locality='Запоріжжя, Хортицький', area='39'),
#  Estate(title='S Сдам в аренду 2-х комнатную квартиру на Старой Салтовке', price='3 500 грн.', floor='2', storey='3', locality='Харків, Салтівський', area='43'),
#  Estate(title='Простора 1-кімнатна квартира з якісним ремонтом!', price='11 500 грн.', floor='5', storey='10', locality='Хмельницький', area='50'),
#  Estate(title='Новый Люкс, 5 мин пешком м Славутич,  Центральная 21А', price='700 грн.', floor='5', storey='?', locality='Київ, Дарницький', area='20'),
#  Estate(title='Посуточно 3 комнатная квартира', price='1 300 грн.', floor='2', storey='?', locality='Южноукраїнськ', area='68'),
#  Estate(title='2комнатная квартира с ремонтом по самой выгодной цене', price='34 999 $', floor='3', storey='5', locality='Одеса, Хаджибейський', area='45'),
#  Estate(title='Здається 1.5 кімн.новобудова в Боздоші', price='380 $', floor='3', storey='5', locality='Ужгород', area='47'),
#  Estate(title='Терміново! Продаж 1 к квартири ЖК Orange Park Крюківщина Без%', price='38 000 $', floor='3', storey='9', locality='Крюківщина', area='37.20'),
#  Estate(title='Продаж 3 кімнатної квартири ЖК Обухівський ключ м.Обухів 92м2', price='130 000 $', floor='2', storey='10', locality='Обухів', area='92'),
#  Estate(title='Продаж виробничо-складського комплексу 6963 кв.м, вул. Журналістів 9', price='1 050 000 $', floor='?', storey='7', locality='Дніпро, Індустріальний', area='6'),
#  Estate(title='Здається в оренду частина будинку з косметичним ремонтом!', price='8 000 грн.', floor='?', storey='1', locality='Хмельницький', area='54'),
#  Estate(title='Пропонується в оренду затишна 2х кімнатна квартира!', price='9 000 грн.', floor='2', storey='9', locality='Хмельницький', area='54'),
#  Estate(title='Оренда затишного будинку 140 м.кв. в закритому містечку. с.Нове', price='750 $', floor='?', storey='2', locality='Боярка', area='140'),
#  Estate(title='Оренда торгових площ м.Ківерці', price='150 грн.', floor='2', storey='3', locality='Ківерці', area='350'),
#  Estate(title='Продам 2к квартиру Рабочая(Зелёный Гай)', price='31 000 $', floor='2', storey='5', locality='Дніпро, Чечеловский', area='51.50'),
#  Estate(title='Стильна 2х кімнатна квартира в новобудові!', price='650 $', floor='4', storey='10', locality='Хмельницький', area='80'),
#  Estate(title='Погодинно ,подобово!', price='400 грн.', floor='2', storey='?', locality='Полтава', area='35'),
#  Estate(title='Без%сдам 1к м.Харківська, ЖК Лебединий,Ревуцького 40Б', price='14 500 грн.', floor='7', storey='25', locality='Київ, Дарницький', area='45'),
#  Estate(title='Будинок Вишеньки  києвом подобово', price='1 400 грн.', floor='?', storey='?', locality='Вишеньки', area='180'),
#  Estate(title='Супер предложение. Аренда помещения 86 метров Варшавский 2 дом 15.2', price='20 $', floor='1', storey='26', locality='Київ, Подільський', area='86'),
#  Estate(title='Продам в Краснополье', price='40 000 $', floor='?', storey='1', locality='Дніпро, Шевченківський', area='65'),
#  Estate(title='Руслан и Людмила 2-комн квартира. Прямой вид моря.', price='130 000 €', floor='19', storey='21', locality='Одеса, Хаджибейський', area='70'),
#  Estate(title='Продам гараж на Павловом Поле', price='10 000 $', floor='?', storey='?', locality='Харків, Слобідський', area='24'),
#  Estate(title='3-комн.квартира 87 м.кв. в длительную рассрочку', price='65 000 $', floor='3', storey='19', locality='Одеса, Київський', area='90'),
#  Estate(title='Участок 9 га под жилую застройку, рядом лес, с. Богдановка', price='550 $', floor='?', storey='?', locality='Богданівка', area='?'),
#  Estate(title='Здам 2 кімнатну квартиру для орендарів зі своїми меблями і технікою!', price='11 000 грн.', floor='8', storey='10', locality='Хмельницький', area='72'),
#  Estate(title='Общежитие в Киеве Хостел Дешево Метро Позняки Харьковская', price='140 грн.', floor='?', storey='?', locality='Київ, Дарницький', area='?'),
#  Estate(title='Готова до заселення 2-к квартира в ЖК PLC (СПП)', price='150 000 $', floor='3', storey='4', locality='Підгірці', area='59.60'),
#  Estate(title='Здам в оренду комфортну та затишну 4х-кімнатну квартиру!', price='18 000 грн.', floor='5', storey='10', locality='Хмельницький', area='140'),
#  Estate(title='Продаж готової 3к квартири під єОселю в Ірпені', price='62 000 $', floor='3', storey='3', locality='Ірпінь', area='84.80'),
#  Estate(title='Продам будинок', price='310 000 грн.', floor='?', storey='1', locality='Чапаєвка', area='80'),
#  Estate(title='Дача Участок с фундаментом Участок', price='5 000 $', floor='?', storey='?', locality='Ізмаїл', area='?'),
#  Estate(title='Будинок газифікований', price='8 000 $', floor='?', storey='1', locality='Борзна', area='56'),
#  Estate(title='Продаж 2 кімнатної квартири по вул. Чигиринська', price='57 000 $', floor='1', storey='9', locality='Львів, Шевченківський', area='47.60'),
#  Estate(title='Аренда! Сдам 2к квартиру Гомельская, Рабочая, пр-т И. Мазепи,  Пушкина', price='7 700 грн.', floor='5', storey='5', locality='Дніпро, Центральний', area='45'),
#  Estate(title='Гостомель,3 к. Кварт.  100м, Сертифікат', price='50 000 $', floor='3', storey='4', locality='Гостомель', area='100'),
#  Estate(title='Задається затишна двокімнатна квартир з чудовим ремонтом!', price='7 000 грн.', floor='1', storey='5', locality='Хмельницький', area='56'),
#  Estate(title='Долгосрочная аренда однокомнатной квартиры СМАРТ', price='6 800 грн.', floor='3', storey='7', locality='Київ, Святошинський', area='31'),
#  Estate(title='Продаж частини будинку в Черкасах', price='39 000 $', floor='?', storey='1', locality='Черкаси', area='50'),
#  Estate(title='2к. посуточно, Киев, метро Черниговская, Лесная', price='700 грн.', floor='4', storey='?', locality='Київ, Деснянський', area='50'),
#  Estate(title='Сдам комнату м. Пушкинская', price='1 500 грн.', floor='3', storey='5', locality='Харків, Шевченківський ', area='24'),
#  Estate(title='Сдаю посуточно  свою 1к кв люкс студия ЦЕНТР ул Шоссейная', price='1 100 грн.', floor='4', storey='?', locality='Миколаїв, Заводський', area='40'),
#  Estate(title='Хостел. Общежитие. Печерский район. М. Дружбы народов. Без посредников', price='90 грн.', floor='?', storey='?', locality='Київ, Печерський', area='?'),
#  Estate(title='2к квартира поруч з Оперним Театром, Золоті Ворота', price='1 500 грн.', floor='2', storey='?', locality='Київ, Шевченківський', area='80'),
#  Estate(title='Оренда для перукаря ,стиліста ,колориста,лашмейкера', price='1 000 грн.', floor='?', storey='4', locality='Коропчик', area='100'),
#  Estate(title='Продажа 2-комн.кв. район Набережной', price='24 900 $', floor='1', storey='5', locality='Запоріжжя, Вознесенівський', area='47'),
#  Estate(title='Продам дом в Шевченковском районе', price='25 500 $', floor='?', storey='1', locality='Запоріжжя, Шевченківський', area='64.80'),
#  Estate(title='Подобова оренда Центр, Пушкінська (вул. Садова, 1) 4 спальних місця', price='700 грн.', floor='2', storey='?', locality='Харків, Київський', area='75'),
#  Estate(title='1к квартира студия ЖК Комфорт Таун посуточно', price='900 грн.', floor='5', storey='?', locality='Київ, Дніпровський', area='34'),
#  Estate(title='Недорого .Почасово.Посуточно', price='400 грн.', floor='1', storey='?', locality='Полтава', area='40'),
#  Estate(title='Комната в комуне Филатова Варненская Интосана', price='1 500 грн.', floor='1', storey='5', locality='Одеса, Хаджибейський', area='10'),
#  Estate(title='Продам участок 25 соток под застройку, жилая улица с. Требухов', price='1 100 $', floor='?', storey='?', locality='Требухів', area='?'),
#  Estate(title='1-кімнатна квартира в центрі міста', price='26 000 $', floor='2', storey='4', locality='Черкаси', area='26'),
#  Estate(title='Продажа Дом 130м2 4 сотки Киев набережная Днепра', price='150 000 $', floor='?', storey='3', locality='Київ, Оболонський', area='130.10'),
#  Estate(title='Продам 1-к квартиру вул.Чорновола 235', price='23 500 $', floor='5', storey='5', locality='Черкаси', area='30'),
#  Estate(title='Теплый Новострой посуточн/почасов 1к кв м.Холодная гора,ЮЖД, Госпиталь', price='500 грн.', floor='2', storey='?', locality='Харків, Холодногірський', area='32'),
#  Estate(title='Оренда 1кім квартира по вул. Городоцька (р-н Скрині)', price='13 000 грн.', floor='2', storey='3', locality='Львів, Залізничний', area='32'),
#  Estate(title='Автономный ЭКО дом в конча-заспе', price='190 000 $', floor='?', storey='2', locality='Козин', area='157'),
#  Estate(title='Продам 2-х комн. ЖК 34 Жемчужина, Бассейная ул. Ремонт. Привоз/Центр.', price='72 000 $', floor='21', storey='25', locality='Одеса, Приморський', area='60'),
#  Estate(title='Продам 2-х кімнатну квартиру, р-н Салтівка, м/р 533.', price='18 500 $', floor='2', storey='5', locality='Харків, Салтівський', area='43'),
#  Estate(title='Фасадный участок 40 сот, бизнес, коммерция, фасад Черниговской трассы', price='550 $', floor='?', storey='?', locality='Велика Димерка', area='?'),
#  Estate(title='Здається 1 кімнатна "НОВОБУДОВА" вул.РУСЬКА (меблі МАЙЯ). Перша здача.', price='300 $', floor='6', storey='9', locality='Чернівці', area='40'),
#  Estate(title='Сдам посуточно /почасово в центре 1-к квартиру ул. Гоголя 2А', price='700 грн.', floor='4', storey='?', locality='Харків, Київський', area='34'),
#  Estate(title='Продаж сучасної 2-х кімнатної квартири', price='105 000 $', floor='2', storey='7', locality='Ужгород', area='63'),
#  Estate(title='Готовий будинок біля лісу. Від забудовника! Підходить під єОселя!', price='89 000 $', floor='?', storey='2', locality='Львів, Шевченківський', area='104'),
#  Estate(title='Центр. Госпиталь. ул. Сумская. ул. Культуры. Зоопарк.', price='500 грн.', floor='6', storey='?', locality='Харків, Київський', area='30'),
#  Estate(title='Дом! Каменная яруга', price='49 000 $', floor='?', storey='1', locality="Кам'яна Яруга", area='90'),
#  Estate(title='Сдам дом у моря,праздники,мероприятия', price='4 500 грн.', floor='?', storey='?', locality='Ліски', area='100'),
#  Estate(title='Продам  четырёх комнатную квартиру.', price='15 000 $', floor='9', storey='9', locality='Долинська', area='83.30'),
#  Estate(title='Аренда дома 5к 325м2 18 соток с. Орловщина', price='1 600 $', floor='?', storey='2', locality='Орлівщина', area='325'),
#  Estate(title='‼️ВІЛЬНО!ПОДОБОВО  !Новобуд  центр  Авалон', price='1 350 грн.', floor='13', storey='?', locality='Львів, Галицький', area='52'),
#  Estate(title='Отличная 2-х ком кв на Даманском', price='6 500 грн.', floor='7', storey='9', locality='Краматорськ', area='48'),
#  Estate(title='Продаж 3х кімнатної Бажана 16', price='5 362 726 грн.', floor='8', storey='21', locality='Київ, Дарницький', area='95.40'),
#  Estate(title='Продам квартиру в ЖК Семинарский 2 метро Холодная гора', price='35 000 $', floor='1', storey='9', locality='Харків, Новобоварський', area='36'),
#  Estate(title='Оренда 1 кімнатної квартири з автономкою на Таращанському масиві', price='7 500 грн.', floor='6', storey='8', locality='Біла Церква', area='36'),
#  Estate(title='Здам приміщення в оренду під бізнес', price='320 грн.', floor='1', storey='1', locality='Лубни', area='92'),
#  Estate(title='ЖК Рибальский, метро "Почтовая Площадь",  Подол, Право Собственности', price='117 000 $', floor='6', storey='8', locality='Київ, Подільський', area='62'),
#  Estate(title='Оренда приміщення, центр, стометрівка,Коломия', price='952 грн.', floor='1', storey='4', locality='Коломия', area='63'),
#  Estate(title='Здам приміщення в оренду', price='350 грн.', floor='2', storey='3', locality='Лубни', area='50'),
#  Estate(title='Здам в оренду приміщення торгового павільону на територіі міського рин', price='180 грн.', floor='1', storey='1', locality='Лубни', area='128'),
#  Estate(title='Підприємство продає  виробничі, офісні, складські приміщення.', price='310 000 $', floor='?', storey='2', locality='Звенигородка', area='6'),
#  Estate(title='Здам в оренду не житлове приміщення під будь який вид діяльності.', price='270 грн.', floor='1', storey='2', locality='Київ, Шевченківський', area='82'),
#  Estate(title='Квартиры Посуточно Почасово 3-комн. Люкс. 8-сп. мест', price='1 200 грн.', floor='2', storey='?', locality='Черкаси', area='112'),
#  Estate(title='1500грн месяц проживания Киевское Общежитие! Метро Оболонь! Недорого!', price='1 500 грн.', floor='1', storey='5', locality='Київ, Подільський', area='170'),
#  Estate(title='Продам квартиру в Виа Рома', price='35 300 $', floor='4', storey='10', locality='Одеса, Київський', area='33'),
#  Estate(title='Продам однокімнатну квартиру з ремонтом, заходь і живи', price='53 000 $', floor='5', storey='9', locality='Буча', area='39'),
#  Estate(title='Здається 1-кімнатна чешка', price='170 $', floor='9', storey='9', locality='Чернівці', area='40'),
#  Estate(title='Продаж апартаментів Закарпаття Свалява Квітка Полонини', price='102 000 $', floor='4', storey='7', locality='Свалява', area='44'),
#  Estate(title='Дачный участок Новопавловские сады', price='12 000 грн.', floor='?', storey='?', locality='Іванівка', area='?'),
#  Estate(title='Центр міста,1кімн., по Княгинен, біля ринку, парку', price='29 200 $', floor='3', storey='12', locality='Івано-Франківськ', area='39'),
#  Estate(title='Продаю,Центр,1-кімн.,Галицька-Княгинен', price='28 200 $', floor='8', storey='12', locality='Івано-Франківськ', area='42'),
#  Estate(title='ПРОДАЮ, ЦЕНТР міста, 2к., 2пов., 71м.кв.,  Княгинен', price='50 000 $', floor='2', storey='12', locality='Івано-Франківськ', area='71'),
#  Estate(title='ПРодаю, 2-х кімнатну, Центр міста, Бандери-Височана', price='43 800 $', floor='12', storey='14', locality='Івано-Франківськ', area='59'),
#  Estate(title='Здана, Центр,Трикімнатна, 98м.кв., ліфт працює, (Бандери-Сахарова)', price='42 000 $', floor='12', storey='12', locality='Івано-Франківськ', area='98'),
#  Estate(title='Оренда приміщення на Автовокзалі', price='8 000 грн.', floor='?', storey='?', locality='Кривий Ріг, Саксаганський', area='58.90'),
#  Estate(title='Продаж 2к 54.9м2 ЖК Paradise Avenue, Крюківщина від на річку', price='49 990 $', floor='11', storey='16', locality='Крюківщина', area='54.90'),
#  Estate(title='сдам 3х комн квартиру  6 ст Фонтана ул Ивана Франко', price='7 000 грн.', floor='2', storey='5', locality='Одеса, Приморський', area='60'),
#  Estate(title='2 кім. Порт сіті район Автостанції подобово', price='550 грн.', floor='4', storey='?', locality='Луцьк', area='49'),
#  Estate(title='В оренду пропонується затишна та сучасна 2х кімнатна квартира!', price='8 000 грн.', floor='3', storey='5', locality='Хмельницький', area='56'),
#  Estate(title='Військовий госпіталь!Центр !Новий рік', price='400 грн.', floor='3', storey='?', locality='Полтава', area='40'),
#  Estate(title='Продам дачний будинок.', price='25 000 $', floor='?', storey='2', locality='Хмельницький', area='67'),
#  Estate(title='Срочная продажа.Будинок Дом Голосеевский р-н.Участок.', price='55 000 $', floor='?', storey='2', locality='Київ, Печерський', area='100'),
#  Estate(title='3к.Посуточно,Почасово.метро Левобережная рядом', price='800 грн.', floor='5', storey='?', locality='Київ, Дніпровський', area='70'),
#  Estate(title='!!!Ціни від 1100!Готель-ресторан «Смерекова Хата» ,Славсько', price='1 100 грн.', floor='?', storey='?', locality='Славське', area='?'),
#  Estate(title='Продам/сдам 64 Га в Циркунах', price='4 000 $', floor='?', storey='?', locality='Циркуни', area='?'),
#  Estate(title='Продається діючий бізнес Ananasik cafe', price='16 000 $', floor='1', storey='3', locality='Ужгород', area='86'),
#  Estate(title='Продається квартира під бізнес на Київській', price='46 000 $', floor='1', storey='5', locality='Житомир, Центр', area='29'),
#  Estate(title='Квартира 1 комнатная', price='8 800 $', floor='3', storey='5', locality='Нікополь', area='37'),
#  Estate(title='Продаж часного будинку', price='10 000 $', floor='?', storey='1', locality='Святогорівка', area='85'),
#  Estate(title='Відпочинок у Карпатах Славське  !БАСЕЙН! ЧАН! САУНА! Без господарів!', price='300 грн.', floor='?', storey='?', locality='Славське', area='400'),
#  Estate(title='Готова до заселення 3х кімнатна квартира! (СПП)', price='180 000 $', floor='3', storey='4', locality='Підгірці', area='75.20'),
#  Estate(title='Продам котедж з частковим ремонтом', price='70 000 $', floor='?', storey='2', locality='Рівне', area='200'),
#  Estate(title='Квартира погодинно,доб', price='450 грн.', floor='3', storey='?', locality='Харків, Слобідський', area='18'),
#  Estate(title='1к Вишуканий ремонт, умебльована з технікою.', price='60 000 $', floor='8', storey='10', locality='Вінниця, Замостянський', area='46'),
#  Estate(title='Оренда/продаж складу', price='100 $', floor='?', storey='?', locality='Федорівка', area='1'),
#  Estate(title='ЖК Дмитриевский, 3 комнаты, 52 кв.м', price='60 000 $', floor='1', storey='20', locality='Одеса, Київський', area='52'),
#  Estate(title='Центр.Староєврейська 20', price='700 грн.', floor='3', storey='?', locality='Львів, Галицький', area='40'),
#  Estate(title='Чудова пропозиція від забудовника!', price='23 700 $', floor='3', storey='5', locality='Гостомель', area='37.53'),
#  Estate(title='Продаж приміщення на першому поверсі 67-450кв.м. вул.Тургенівська', price='1 170 $', floor='1', storey='10', locality='Ірпінь', area='250'),
#  Estate(title='Відпочинок в Карпатах, недалеко від Буковелю, оренда котеджу', price='2 500 грн.', floor='?', storey='?', locality='Микуличин', area='126'),
#  Estate(title='Модульні будинки під ключ.', price='780 000 грн.', floor='?', storey='1', locality='Глеваха', area='40'),
#  Estate(title='Продам свою квартиру в жк Карамель', price='18 900 $', floor='5', storey='9', locality='Харків, Холодногірський', area='19'),
#  Estate(title='Сдается в аренду 75 (возможно под склад, СТО) ул. Бориспольская, 19', price='70 грн.', floor='1', storey='1', locality='Київ, Дарницький', area='75'),
#  Estate(title='Продаж  будинка. Ужгород.', price='105 000 $', floor='?', storey='1', locality='Ужгород', area='180'),
#  Estate(title='трикімнатна квартира, район РПЗ.', price='950 000 грн.', floor='2', storey='9', locality='Сміла', area='67'),
#  Estate(title='Земельный участок ул. Онежская рядом с ул Петрозаводская', price='17 000 $', floor='?', storey='?', locality='Дніпро, Амур-Нижньодніпровський ', area='?'),
#  Estate(title='Продам двухкомнатную квартиру .', price='14 000 $', floor='1', storey='5', locality='Краматорськ', area='49'),
#  Estate(title='ЖК Вілла Магнолія. З ремонтом! 65,7+6м.кв', price='134 000 $', floor='2', storey='4', locality='Львів, Сихівський', area='72'),
#  Estate(title='Продам земельну ділянку 0.12га', price='120 000 $', floor='?', storey='?', locality='Трускавець', area='?'),
#  Estate(title='Оренда земельної ділянки  5 соток', price='500 грн.', floor='?', storey='?', locality='Жовті  Води', area='?'),
#  Estate(title='1-кімнатна квартира в центрі з Євроремонтом. Аренди не має', price='37 000 $', floor='3', storey='5', locality="Кам'янка", area='37'),
#  Estate(title='Продам кормеційне приміщення 98 кв.м, ЖК "Європейський квартал"', price='1 900 $', floor='?', storey='?', locality='Полтава', area='75'),
#  Estate(title='Оренда 3-х кімнатної квартири з хорошим косметичним ремонтом!', price='10 000 грн.', floor='7', storey='10', locality='Хмельницький', area='65'),
#  Estate(title='Продам 3к м.Дарница ПЕШКОМ 5мин Жмаченко 8 БЕЗОПАСНЫЙ РАЙОН Киева', price='110 000 $', floor='12', storey='16', locality='Київ, Дніпровський', area='70'),
#  Estate(title='Продам дом. Сухой лиман', price='69 000 $', floor='?', storey='2', locality='Сухий Лиман', area='200'),
#  Estate(title='Открытие Современного Хостела! Киев, Метро ВДНХ, Теремки! Владелец', price='90 грн.', floor='?', storey='?', locality='Київ, Голосіївський', area='?'),
#  Estate(title='Продаж 2 кімнатної квартири по вул. Чигиринська', price='57 000 $', floor='1', storey='9', locality='Львів, Шевченківський', area='47.60'),
#  Estate(title='Продам свой участок в селе Помокли', price='2 000 $', floor='?', storey='?', locality='Помоклі', area='?'),
#  Estate(title='Гостомель,3 к. Кварт.  100м, Сертифікат', price='50 000 $', floor='3', storey='4', locality='Гостомель', area='100'),
#  Estate(title='Долгосрочная аренда однокомнатной квартиры СМАРТ', price='6 800 грн.', floor='3', storey='7', locality='Київ, Святошинський', area='31'),
#  Estate(title='Продаж частини будинку в Черкасах', price='39 000 $', floor='?', storey='1', locality='Черкаси', area='50'),
#  Estate(title='СДАМ ОТЛИЧНУЮ 3 комнатную квартиру  ЦЕНТР есть ВИДЕО и Балкон', price='10 800 грн.', floor='2', storey='4', locality='Одеса, Приморський', area='55'),
#  Estate(title='2к. посуточно, Киев, метро Черниговская, Лесная', price='700 грн.', floor='4', storey='?', locality='Київ, Деснянський', area='50'),
#  Estate(title='Сдаю посуточно  свою 1к кв люкс студия ЦЕНТР ул Шоссейная', price='1 100 грн.', floor='4', storey='?', locality='Миколаїв, Заводський', area='40'),
#  Estate(title='Продажа 2-комн.кв. район Набережной', price='24 900 $', floor='1', storey='5', locality='Запоріжжя, Вознесенівський', area='47'),
#  Estate(title='Продам дом в Шевченковском районе', price='25 500 $', floor='?', storey='1', locality='Запоріжжя, Шевченківський', area='64.80'),
#  Estate(title='Сдам 3х комнатную квартиру, пр. Соборный 152Б, Пушкина, ЗАГС.', price='800 грн.', floor='5', storey='?', locality='Запоріжжя, Олександрiвський', area='58'),
#  Estate(title='Продам ділянку у Лісі', price='650 $', floor='?', storey='?', locality='Чернігів', area='?'),
#  Estate(title='AL Продається 1-кімнатна квартира р-н парку Перемоги(єОселя)', price='31 000 $', floor='9', storey='12', locality='Черкаси', area='39'),
#  Estate(title='Оренда затишного колівінгу на Мінській, Рокоссовського 8', price='8 000 грн.', floor='5', storey='9', locality='Київ, Оболонський', area='70'),
#  Estate(title='Подобова оренда Центр, Пушкінська (вул. Садова, 1) 4 спальних місця', price='700 грн.', floor='2', storey='?', locality='Харків, Київський', area='75'),
#  Estate(title='1к квартира студия ЖК Комфорт Таун посуточно', price='900 грн.', floor='5', storey='?', locality='Київ, Дніпровський', area='34'),
#  Estate(title='Комната в комуне Филатова Варненская Интосана', price='1 500 грн.', floor='1', storey='5', locality='Одеса, Хаджибейський', area='10'),
#  Estate(title='Оренда квартири подобово 2 кім люкс, жилмасів Придніпровський джакузі', price='1 200 грн.', floor='2', storey='?', locality='Дніпро, Самарський', area='63'),
#  Estate(title='Сдам 3х комнатную квартиру улГорбатка8 3й эт', price='15 000 грн.', floor='3', storey='10', locality='Южне', area='90'),
#  Estate(title='1-кімнатна квартира в центрі міста', price='26 000 $', floor='2', storey='4', locality='Черкаси', area='26'),
#  Estate(title='2 кімнатна квартира м. Ужгород', price='45 000 $', floor='2', storey='5', locality='Ужгород', area='62'),
#  Estate(title='Оренда подобово 2 комнатная квартира жилмассив Приднепровский ремонт', price='1 200 грн.', floor='1', storey='?', locality='Дніпро, Самарський', area='43'),
#  Estate(title='Продається будинок', price='5 000 $', floor='?', storey='1', locality='Глибівка', area='78'),
#  Estate(title='Таунхаус Квартира Киев Осокорки Дом возле Озера Жилье 120м2 Собственик', price='62 000 $', floor='?', storey='2', locality='Київ, Дарницький', area='120'),
#  Estate(title='Без комиссии, Совиньон, длительная аренда дома для счастливой жизни', price='1 350 $', floor='?', storey='2', locality='Одеса, Київський', area='250'),
#  Estate(title='Сдам 2-х комнатную М. Университет, м. Держпром (ул. Алчевских 5)', price='6 500 грн.', floor='4', storey='4', locality='Степова', area='60'),
#  Estate(title='Подобово кімнати у власному будинку  м. Мукачево Росвигово .', price='500 грн.', floor='2', storey='?', locality='Мукачеве', area='120'),
#  Estate(title='Продам 1-к квартиру вул.Чорновола 235', price='23 500 $', floor='5', storey='5', locality='Черкаси', area='30'),
#  Estate(title='Оренда офіса 10/25/55 м2', price='100 грн.', floor='2', storey='2', locality="Кам'янське", area='55'),
#  Estate(title='Продам 2-х кімнатну квартиру, р-н Салтівка, м/р 533.', price='18 500 $', floor='2', storey='5', locality='Харків, Салтівський', area='43'),
#  Estate(title='продам 3- кім сирець', price='52 000 $', floor='8', storey='12', locality='Івано-Франківськ', area='100'),
#  Estate(title='Квартира подобово люкс Центр, Мечникова, Нагорка, Вокзал, Мост-сіті', price='1 200 грн.', floor='2', storey='?', locality='Дніпро, Соборний', area='47'),
#  Estate(title='Здається 1 кімнатна "НОВОБУДОВА" вул.РУСЬКА (меблі МАЙЯ). Перша здача.', price='300 $', floor='6', storey='9', locality='Чернівці', area='40'),
#  Estate(title='Реальная! 1к S 40м ,3\\9эт в сданном новострое ЖК Гидропарк.Q', price='15 900 $', floor='3', storey='9', locality='Харків, Київський', area='40'),
#  Estate(title='Каверина  Робоча Зелений  Гай', price='45 500 $', floor='4', storey='5', locality='Дніпро, Центральний', area='46'),
#  Estate(title='Дом! Каменная яруга', price='49 000 $', floor='?', storey='1', locality="Кам'яна Яруга", area='90'),
#  Estate(title='Без %! ЖК "Варшавський плюс". Продам 1к Правди просп., 49. "єОселя"', price='87 000 $', floor='10', storey='26', locality='Київ, Подільський', area='43.10'),
#  Estate(title='ЛУЧШИЙ ХОСТЕЛ КИЕВА. Хозяин. Без комиссии. Без посредников. Общежитие', price='90 грн.', floor='?', storey='?', locality='Київ, Дарницький', area='?'),
#  Estate(title='Продам земельну ділянку', price='6 500 $', floor='?', storey='?', locality='Розсоша', area='?'),
#  Estate(title='Продаж 3х кімнатної Бажана 16', price='5 362 726 грн.', floor='8', storey='21', locality='Київ, Дарницький', area='95.40'),
#  Estate(title='Продам квартиру в ЖК Семинарский 2 метро Холодная гора', price='35 000 $', floor='1', storey='9', locality='Харків, Новобоварський', area='36'),
#  Estate(title='Подобово 2-к. центр, вул. Князя Романа', price='1 250 грн.', floor='3', storey='?', locality='Львів, Галицький', area='57'),
#  Estate(title='Оренда 1 кімнатної квартири з автономкою на Таращанському масиві', price='7 500 грн.', floor='6', storey='8', locality='Біла Церква', area='36'),
#  Estate(title='Продам 4х перепланированную в 3х квартиру Мирноград', price='6 500 $', floor='4', storey='5', locality='Мирноград', area='60'),
#  Estate(title='Подобово 2к, центр, паркінг, вул. І.Франка', price='1 400 грн.', floor='4', storey='?', locality='Львів, Галицький', area='125'),
#  Estate(title='Оренда приміщення, центр, стометрівка,Коломия', price='952 грн.', floor='1', storey='4', locality='Коломия', area='63'),
#  Estate(title='еОселя!!! 1 комнатная квартира возле свежего воздуха и сосен', price='51 000 $', floor='4', storey='5', locality='Ірпінь', area='41.80'),
#  Estate(title='Підприємство продає  виробничі, офісні, складські приміщення.', price='310 000 $', floor='?', storey='2', locality='Звенигородка', area='6'),
#  Estate(title='Офис, ресторан, 478 кв.м, терраса, этаж 2', price='200 грн.', floor='2', storey='10', locality='Запоріжжя, Вознесенівський', area='478'),
#  Estate(title='Здам подобово 1к. кв-ру, 10хв. до метро Г.Дніпра 3, ЗНИЖКИ- В ОПИСІ !!', price='700 грн.', floor='6', storey='?', locality='Київ, Печерський', area='30'),
#  Estate(title='Двокімнатна квартира в центрі міста', price='50 000 $', floor='3', storey='5', locality='Ірпінь', area='63.90'),
#  Estate(title='Будинок новий Чернівці', price='295 000 $', floor='?', storey='3', locality='Чернівці', area='290'),
#  Estate(title='Будинок газифікований', price='8 000 $', floor='?', storey='1', locality='Борзна', area='56'),
#  Estate(title='Продаж 2 кімнатної квартири по вул. Чигиринська', price='57 000 $', floor='1', storey='9', locality='Львів, Шевченківський', area='47.60'),
#  Estate(title='Аренда! Сдам 2к квартиру Гомельская, Рабочая, пр-т И. Мазепи,  Пушкина', price='7 700 грн.', floor='5', storey='5', locality='Дніпро, Центральний', area='45'),
#  Estate(title='Гостомель,3 к. Кварт.  100м, Сертифікат', price='50 000 $', floor='3', storey='4', locality='Гостомель', area='100'),
#  Estate(title='Задається затишна двокімнатна квартир з чудовим ремонтом!', price='7 000 грн.', floor='1', storey='5', locality='Хмельницький', area='56'),
#  Estate(title='Долгосрочная аренда однокомнатной квартиры СМАРТ', price='6 800 грн.', floor='3', storey='7', locality='Київ, Святошинський', area='31'),
#  Estate(title='Продаж частини будинку в Черкасах', price='39 000 $', floor='?', storey='1', locality='Черкаси', area='50'),
#  Estate(title='СДАМ ОТЛИЧНУЮ 3 комнатную квартиру  ЦЕНТР есть ВИДЕО и Балкон', price='10 800 грн.', floor='2', storey='4', locality='Одеса, Приморський', area='55'),
#  Estate(title='2к. посуточно, Киев, метро Черниговская, Лесная', price='700 грн.', floor='4', storey='?', locality='Київ, Деснянський', area='50'),
#  Estate(title='Сдаю посуточно  свою 1к кв люкс студия ЦЕНТР ул Шоссейная', price='1 100 грн.', floor='4', storey='?', locality='Миколаїв, Заводський', area='40'),
#  Estate(title='Уютная  1 комн.кв, в Буче , цент. Рядом ТРЦ Авенир Плаза', price='550 грн.', floor='13', storey='?', locality='Буча', area='32'),
#  Estate(title='Трехкомнатная полнометражная квартира с ремонтом', price='56 000 $', floor='2', storey='3', locality='Запоріжжя, Дніпровський', area='64'),
#  Estate(title='Задається 2-х кімнатна квартира з хорошим ремонтом!', price='8 000 грн.', floor='10', storey='10', locality='Хмельницький', area='54'),
#  Estate(title='Продажа 2-комн.кв. район Набережной', price='24 900 $', floor='1', storey='5', locality='Запоріжжя, Вознесенівський', area='47'),
#  Estate(title='Продам дом в Шевченковском районе', price='25 500 $', floor='?', storey='1', locality='Запоріжжя, Шевченківський', area='64.80'),
#  Estate(title='Оренда затишного колівінгу на Мінській, Рокоссовського 8', price='8 000 грн.', floor='5', storey='9', locality='Київ, Оболонський', area='70'),
#  Estate(title='Подобова оренда Центр, Пушкінська (вул. Садова, 1) 4 спальних місця', price='700 грн.', floor='2', storey='?', locality='Харків, Київський', area='75'),
#  Estate(title='1к квартира студия ЖК Комфорт Таун посуточно', price='900 грн.', floor='5', storey='?', locality='Київ, Дніпровський', area='34'),
#  Estate(title='Недорого .Почасово.Посуточно', price='400 грн.', floor='1', storey='?', locality='Полтава', area='40'),
#  Estate(title='Комната в комуне Филатова Варненская Интосана', price='1 500 грн.', floor='1', storey='5', locality='Одеса, Хаджибейський', area='10'),
#  Estate(title='Продам участок 25 соток под застройку, жилая улица с. Требухов', price='1 100 $', floor='?', storey='?', locality='Требухів', area='?'),
#  Estate(title='1-кімнатна квартира в центрі міста', price='26 000 $', floor='2', storey='4', locality='Черкаси', area='26'),
#  Estate(title='Продажа Дом 130м2 4 сотки Киев набережная Днепра', price='150 000 $', floor='?', storey='3', locality='Київ, Оболонський', area='130.10'),
#  Estate(title='Новий будинок', price='47 000 $', floor='?', storey='1', locality='Кропивницький, Фортечний', area='60'),
#  Estate(title='Продажа 3-х комн жк Варшавский Плюс ул. Олександра Олеся 8/17 Без %', price='168 000 $', floor='23', storey='26', locality='Київ, Подільський', area='64'),
#  Estate(title='Продаю будинок 267м2 з євроремонтом та меблями 10км до Києва', price='290 000 $', floor='?', storey='2', locality='Нове', area='267'),
#  Estate(title='Продам 1-к квартиру вул.Чорновола 235', price='23 500 $', floor='5', storey='5', locality='Черкаси', area='30'),
#  Estate(title='Продам 2-х комн. ЖК 34 Жемчужина, Бассейная ул. Ремонт. Привоз/Центр.', price='72 000 $', floor='21', storey='25', locality='Одеса, Приморський', area='60'),
#  Estate(title='Продам 2-х кімнатну квартиру, р-н Салтівка, м/р 533.', price='18 500 $', floor='2', storey='5', locality='Харків, Салтівський', area='43'),
#  Estate(title='Квартира подобово люкс Центр, Мечникова, Нагорка, Вокзал, Мост-сіті', price='1 200 грн.', floor='2', storey='?', locality='Дніпро, Соборний', area='47'),
#  Estate(title='Фасадный участок 40 сот, бизнес, коммерция, фасад Черниговской трассы', price='550 $', floor='?', storey='?', locality='Велика Димерка', area='?'),
#  Estate(title='Здається 1 кімнатна "НОВОБУДОВА" вул.РУСЬКА (меблі МАЙЯ). Перша здача.', price='300 $', floor='6', storey='9', locality='Чернівці', area='40'),
#  Estate(title='Реальная! 1к S 40м ,3\\9эт в сданном новострое ЖК Гидропарк.Q', price='15 900 $', floor='3', storey='9', locality='Харків, Київський', area='40'),
#  Estate(title='Готовий будинок біля лісу. Від забудовника! Підходить під єОселя!', price='89 000 $', floor='?', storey='2', locality='Львів, Шевченківський', area='104'),
#  Estate(title='Центр. Госпиталь. ул. Сумская. ул. Культуры. Зоопарк.', price='500 грн.', floor='6', storey='?', locality='Харків, Київський', area='30'),
#  Estate(title='Дом! Каменная яруга', price='49 000 $', floor='?', storey='1', locality="Кам'яна Яруга", area='90'),
#  Estate(title='ШИКАРНАЯ 3к квартира ЖК Respublika Республика Теремковская 4а Теремки', price='250 000 $', floor='3', storey='9', locality='Київ, Голосіївський', area='90'),
#  Estate(title='Продаж 2 кім кв ЖК "Лісова Казка" Деснянський р-н Лісний Лісова', price='90 000 $', floor='5', storey='10', locality='Київ, Деснянський', area='52'),
#  Estate(title='1 кім в Центрі в закритому Містечку з паркінгом .Єоселя', price='65 000 $', floor='9', storey='12', locality='Івано-Франківськ', area='44'),
#  Estate(title='Сдам дом у моря,праздники,мероприятия', price='4 500 грн.', floor='?', storey='?', locality='Ліски', area='100'),
#  Estate(title='Отличная 2-х ком кв на Даманском', price='6 500 грн.', floor='7', storey='9', locality='Краматорськ', area='48'),
#  Estate(title='Продаж 3х кімнатної Бажана 16', price='5 362 726 грн.', floor='8', storey='21', locality='Київ, Дарницький', area='95.40'),
#  Estate(title='Продам квартиру в ЖК Семинарский 2 метро Холодная гора', price='35 000 $', floor='1', storey='9', locality='Харків, Новобоварський', area='36'),
#  Estate(title='Оренда 1 кімнатної квартири з автономкою на Таращанському масиві', price='7 500 грн.', floor='6', storey='8', locality='Біла Церква', area='36'),
#  Estate(title='ЖК Рибальский, метро "Почтовая Площадь",  Подол, Право Собственности', price='117 000 $', floor='6', storey='8', locality='Київ, Подільський', area='62'),
#  Estate(title='Оренда приміщення, центр, стометрівка,Коломия', price='952 грн.', floor='1', storey='4', locality='Коломия', area='63'),
#  Estate(title='Здам приміщення в оренду', price='350 грн.', floor='2', storey='3', locality='Лубни', area='50'),
#  Estate(title='Здам в оренду приміщення торгового павільону на територіі міського рин', price='180 грн.', floor='1', storey='1', locality='Лубни', area='128'),
#  Estate(title='Підприємство продає  виробничі, офісні, складські приміщення.', price='310 000 $', floor='?', storey='2', locality='Звенигородка', area='6'),
#  Estate(title='Дом с ремонтом 107 м р-н "20 больницы"/лес/Днепр', price='50 000 $', floor='?', storey='1', locality='Дніпро, Амур-Нижньодніпровський ', area='107'),
#  Estate(title='Аренда помещений, Мафы, Магазины, Павильоны, Киоски, Склады, и т.д.', price='4 000 грн.', floor='?', storey='?', locality='Запоріжжя, Комунарський', area='16'),
#  Estate(title='НОВЫЙ ХОСТЕЛ . Метро Лукьяновская - 5 минут ходьбы . Общежитие дешево', price='90 грн.', floor='?', storey='?', locality='Київ, Шевченківський', area='?'),
#  Estate(title='Продам 3 комнатную квартиру Павлово Поле', price='40 000 $', floor='3', storey='5', locality='Харків, Шевченківський ', area='54'),
#  Estate(title='Продам дом в Жихаре под ремонт .Отличное место .Хорошая ценаTB', price='13 000 $', floor='?', storey='1', locality="Харків, Основ'янський", area='72'),
#  Estate(title='Оренда 1 к з АГВ, вул. Шевченка р-н мед.ун', price='10 000 грн.', floor='4', storey='9', locality='Вінниця, Ленінський', area='45'),
#  Estate(title='Продаж елітної новобудови ЖК Avalon Up', price='120 000 $', floor='18', storey='25', locality='Львів, Сихівський', area='50'),
#  Estate(title='Акция! Продам! Срочно! 1- ком. Михайловском городке', price='35 000 $', floor='12', storey='19', locality='Одеса, Хаджибейський', area='42'),
#  Estate(title='2 кімнатна квартира гарного планування', price='55 600 $', floor='7', storey='11', locality='Житомир, Богунський', area='62.99'),
#  Estate(title='Продам 3- х комнатную квартиру возле Крытого рынка по ул.Парковой', price='24 000 $', floor='4', storey='5', locality='Краматорськ', area='60'),
#  Estate(title='Здам  однокімнатну квартиру в м.Василькові. Власник.', price='5 000 грн.', floor='1', storey='5', locality='Васильків', area='32'),
#  Estate(title='Продам свой участок в селе Помокли', price='2 000 $', floor='?', storey='?', locality='Помоклі', area='?'),
#  Estate(title='Продам 2 кімн.Глушко 33.500', price='33 500 $', floor='4', storey='9', locality='Одеса, Київський', area='50'),
#  Estate(title='Гараж в АК-20А (Інструментальна) (КамАЗ-центр)', price='6 700 $', floor='?', storey='?', locality='Чернігів', area='36'),
#  Estate(title='Продажа дома на берегу Днепра в КГ Marinero Residence ,Киев ,Осокорки.', price='377 000 $', floor='?', storey='2', locality='Славутич', area='220'),
#  Estate(title='Продаж 2-к квартири у ЖК Парк Таун. Мінімальне оформлення!', price='55 000 $', floor='5', storey='9', locality='Буча', area='59.60'),
#  Estate(title='Продам 2х кімнатну в елітній новобудові', price='55 500 $', floor='14', storey='19', locality='Одеса, Київський', area='44'),
#  Estate(title='3к 69,3м2 Сабурова 9/61 Лифаря Червоної Калини Маяковського', price='55 000 $', floor='1', storey='9', locality='Київ, Деснянський', area='69.30'),
#  Estate(title='Смарт квартири центр', price='500 грн.', floor='4', storey='?', locality='Ужгород', area='20'),
#  Estate(title='Без комісії! ЖК преміум класу  вул. Звіринецька, 47,', price='35 000 грн.', floor='8', storey='9', locality='Київ, Печерський', area='130'),
#  Estate(title='Здам гараж  на Русановці.', price='3 200 грн.', floor='?', storey='?', locality='Київ, Дніпровський', area='24'),
#  Estate(title='1к 61м Ушинського 14а Антонова Волинська Уманська Чолоківський', price='92 000 $', floor='21', storey='22', locality="Київ, Солом'янський", area='61'),
#  Estate(title='Оренда квартири подобово 2 кім люкс, жилмасів Придніпровський джакузі', price='1 200 грн.', floor='2', storey='?', locality='Дніпро, Самарський', area='63'),
#  Estate(title='Сдам 3х комнатную квартиру улГорбатка8 3й эт', price='15 000 грн.', floor='3', storey='10', locality='Южне', area='90'),
#  Estate(title='Здається 5-ти кімнатна квартира у 2 рівні на вул.ЩЕРБАНЮКА + ГАРАЖ.', price='400 $', floor='2', storey='3', locality='Чернівці', area='240'),
#  Estate(title='2 кімнатна квартира м. Ужгород', price='45 000 $', floor='2', storey='5', locality='Ужгород', area='62'),
#  Estate(title='Продам квартиру центр', price='210 000 $', floor='7', storey='7', locality='Київ, Шевченківський', area='106.50'),
#  Estate(title='Villa Magda Новий Готель біля Термальн басейну "Закарпаття" + парковка', price='950 грн.', floor='?', storey='?', locality='Берегове', area='?'),
#  Estate(title='1к квартира, Лазурний.Власники. Обмін на авто!', price='8 300 $', floor='5', storey='5', locality='Покровськ', area='31'),
#  Estate(title='Без комісії ! Продам 3к. кв вул. Амосова 4 .', price='170 000 $', floor='13', storey='17', locality="Київ, Солом'янський", area='103'),
#  Estate(title='Оренда подобово 2 комнатная квартира жилмассив Приднепровский ремонт', price='1 200 грн.', floor='1', storey='?', locality='Дніпро, Самарський', area='43'),
#  Estate(title='Продається будинок', price='5 000 $', floor='?', storey='1', locality='Глибівка', area='78'),
#  Estate(title='Подобово кімнати у власному будинку  м. Мукачево Росвигово .', price='500 грн.', floor='2', storey='?', locality='Мукачеве', area='120'),
#  Estate(title='Теремки-2 .Продаж. Фасад.  Комерція. 86 м кв. вул. Луценко,12, без %', price='189 000 $', floor='1', storey='8', locality='Київ, Голосіївський', area='85.60'),
#  Estate(title='Оренда офіса 10/25/55 м2', price='100 грн.', floor='2', storey='2', locality="Кам'янське", area='55'),
#  Estate(title='продам 3- кім сирець', price='52 000 $', floor='8', storey='12', locality='Івано-Франківськ', area='100'),
#  Estate(title='Продається будинок с. Бирлівка (Гайсинський р-н)', price='3 500 $', floor='?', storey='1', locality='Бершадь', area='48.10'),
#  Estate(title='Посуточно, почасовое центр города', price='500 грн.', floor='7', storey='?', locality='Суми', area='60'),
#  Estate(title='Здається половина будинку в с. Троещина', price='8 000 грн.', floor='1', storey='1', locality='Київ, Деснянський', area='40'),
#  Estate(title='Продам 4х комнатную квартиру ПЗТО', price='48 500 $', floor='4', storey='5', locality='Павлоград', area='90'),
#  Estate(title='Погодинна оплата тренінгового залу Поділ, Воздвиженка', price='700 грн.', floor='4', storey='4', locality='Київ, Подільський', area='60'),
#  Estate(title='Продаю 3-кімнатну квартиру на Університетській', price='31 987 $', floor='4', storey='4', locality='Запоріжжя, Олександрiвський', area='60'),
#  Estate(title='Каверина  Робоча Зелений  Гай', price='45 500 $', floor='4', storey='5', locality='Дніпро, Центральний', area='46'),
#  Estate(title='Подобово 2-к. центр, вул. Князя Романа', price='1 250 грн.', floor='3', storey='?', locality='Львів, Галицький', area='57'),
#  Estate(title='Продається готовий Таунхаус у Крихівцях', price='66 900 $', floor='?', storey='2', locality='Івано-Франківськ', area='120'),
#  Estate(title='Будинок Креничі довгостроково 200м', price='24 000 грн.', floor='?', storey='2', locality='Креничі', area='200'),
#  Estate(title='Комерційні приміщення у центрі міста!', price='1 700 $', floor='1.20', storey='8', locality='Трускавець', area='686'),
#  Estate(title='Продам 4х перепланированную в 3х квартиру Мирноград', price='6 500 $', floor='4', storey='5', locality='Мирноград', area='60'),
#  Estate(title='Подобово 2к, центр, паркінг, вул. І.Франка', price='1 400 грн.', floor='4', storey='?', locality='Львів, Галицький', area='125'),
#  Estate(title='Оренда кабінету в центрі міста', price='420 $', floor='2', storey='3', locality='Ужгород', area='60'),
#  Estate(title='еОселя!!! 1 комнатная квартира возле свежего воздуха и сосен', price='51 000 $', floor='4', storey='5', locality='Ірпінь', area='41.80'),
#  Estate(title='Офис, ресторан, 478 кв.м, терраса, этаж 2', price='200 грн.', floor='2', storey='10', locality='Запоріжжя, Вознесенівський', area='478'),
#  Estate(title='Оренда гаража в ГСК Київський', price='1 500 грн.', floor='?', storey='?', locality='Вінниця, Замостянський', area='19'),
#  Estate(title='Дом,коттедж-таунхаус  у моря', price='3 500 грн.', floor='?', storey='?', locality='Санжійка', area='75'),
#  Estate(title='Подобово погодинно квартира в Центрі Львова (ціна для двох)', price='600 грн.', floor='1', storey='?', locality='Львів, Галицький', area='36'),
#  Estate(title='Пропонується 2х кімнатна квартира з косметичним ремонтом!', price='6 500 грн.', floor='6', storey='9', locality='Хмельницький', area='56'),
#  Estate(title='Аренда 3-ком Котедж в Одессе на 16 ст.Б.Фонтана', price='700 $', floor='?', storey='2', locality='Одеса, Приморський', area='80'),
#  Estate(title='Сдам длительно 1к. квартиру Южный рынок Таирова Киевский район', price='6 499 грн.', floor='7', storey='9', locality='Одеса, Київський', area='37'),
#  Estate(title='Здам 1к. кв. ЖК Зарічний, будинок з генератором і укриттям.', price='18 000 грн.', floor='5', storey='24', locality='Київ, Дарницький', area='51'),
#  Estate(title='двокімнатна квартира у центрі міста', price='1 000 грн.', floor='2', storey='?', locality='Львів, Галицький', area='45'),
#  Estate(title='Продам 1 к квартиру м-н Светлый в центре Мирнограда', price='150 000 грн.', floor='2', storey='5', locality='Мирноград', area='23'),
#  Estate(title='Продам маф, каркасний будинок, дача, офіс.', price='11 900 $', floor='?', storey='?', locality='Київ, Шевченківський', area='15'),
#  Estate(title='Здам 1 кім квартиру на ДНСі', price='7 500 грн.', floor='1', storey='5', locality='Біла Церква', area='31'),
#  Estate(title='Продам приватизовану земельный ділянку', price='5 000 $', floor='?', storey='?', locality='Тячів', area='?'),
#  Estate(title='1 кінатна 33,4 м2 без ремонту', price='35 000 $', floor='2', storey='5', locality='Гатне', area='33.40'),
#  Estate(title='Посуточно апартаменты студио. м. Славутич - 10 мин., Осокорки', price='500 грн.', floor='3', storey='?', locality='Київ, Дарницький', area='16'),
# ...
#  Estate(title='Двух комнатная  квартира в центре Черноморска', price='33 500 $', floor='2', storey='5', locality='Чорноморськ', area='42'),
#  Estate(title='Продам 2 кімнатну квартиру в СПЕКТРУМІ', price='91 800 $', floor='6', storey='9', locality='Рівне', area='67'),
#  Estate(title='Аренда 1-ком, Борщаговка, ул.Якуба  Колоса 14, 37метров', price='8 000 грн.', floor='10', storey='16', locality='Київ, Святошинський', area='37'),
#  Estate(title='Оренда 3 х кім квартири.Ближній центр,вул.Тарнавського 3, м.Львів', price='15 000 грн.', floor='1', storey='3', locality='Львів, Галицький', area='80'),
#  Estate(title='2-к квартира Поділя', price='15 000 грн.', floor='2', storey='10', locality='Вінниця, Ленінський', area='69'),
#  Estate(title='Маф ‼️ аренда без комисии Подол Нижний вал Глубочицкая павильон киоск', price='14 900 грн.', floor='?', storey='?', locality='Київ, Подільський', area='20'),
#  Estate(title='X S4 Продам 1 комнатную квартиру Салтовка улица Амосова 40', price='16 000 $', floor='9', storey='12', locality='Харків, Немишлянський', area='32'),
#  Estate(title='Сдаю посуточно квартиру', price='900 грн.', floor='2', storey='?', locality='Ізмаїл', area='35'),
#  Estate(title='Однокімнатна квартира у самому центрі.', price='700 грн.', floor='1', storey='?', locality='Львів, Галицький', area='35'),
#  Estate(title='Продається хата в селі', price='30 000 $', floor='?', storey='1', locality='Родниківка', area='100'),
#  Estate(title='Дво кімнатна квартира на площі ринок', price='900 грн.', floor='3', storey='?', locality='Львів, Галицький', area='60'),
#  Estate(title='Довгострокова оренда Трускавець', price='6 500 грн.', floor='1', storey='5', locality='Трускавець', area='31'),
#  Estate(title='Квартира подобово місто Ізюм', price='600 грн.', floor='1', storey='?', locality='Ізюм', area='45'),
#  Estate(title='Сдам две комнаты в общежитии на Ленпоселке. Продам.', price='3 500 грн.', floor='5', storey='5', locality='Одеса, Хаджибейський', area='36'),
#  Estate(title='Сдам посуточно в центре,больница Мечникова, победа,космическая,тополь', price='850 грн.', floor='4', storey='?', locality='Дніпро, Центральний', area='48'),
#  Estate(title='Гараж на лісовому проспекті', price='3 500 $', floor='?', storey='?', locality='Київ, Деснянський', area='24'),
#  Estate(title='1-кім. Автовокзал. КОНДИЦІОНЕР.  Ціна за добу. Погодинно, подобово.', price='600 грн.', floor='9', storey='?', locality='Рівне', area='31'),
#  Estate(title='Роскошные 2к апартаменты на ул. Саксаганского, 25а (НСК «Олимпийский»)', price='1 200 грн.', floor='4', storey='?', locality='Київ, Печерський', area='53'),
#  Estate(title='Продам 1-кімнатну квартиру . Ювілейний', price='18 000 $', floor='8', storey='9', locality='Обарів', area='21'),
#  Estate(title='Продам 1 кк вул. Алматинська, 41Б', price='47 900 $', floor='14', storey='14', locality='Київ, Дніпровський', area='38'),
#  Estate(title='Однокімнатна квартира від забудовника Мукачево', price='34 331 $', floor='8', storey='8', locality='Мукачеве', area='40.39'),
#  Estate(title='Квартири подобово.', price='800 грн.', floor='3', storey='?', locality="Слов'янськ", area='40'),
#  Estate(title='Без комиссии!Продам дом 160 м2 в Гореничах', price='105 000 $', floor='?', storey='2', locality='Гореничі', area='160'),
#  Estate(title='Сдам квартиру посуточно', price='800 грн.', floor='3', storey='?', locality='Курахове', area='56'),
#  Estate(title='Ділянка 12,4сот під забудову в Конопниці', price='24 000 $', floor='?', storey='?', locality='Конопниця', area='?'),
#  Estate(title='Теплий будинок біля лісу річки та Київського моря без %', price='205 000 $', floor='?', storey='2', locality='Вишгород', area='220'),
#  Estate(title='Центр , 2к роздільна, по вул.Карпатська біля Нафти і газу,', price='6 500 грн.', floor='3', storey='5', locality='Івано-Франківськ', area='45'),
#  Estate(title='2х Квартира на пр.Гагарина', price='57 800 $', floor='2', storey='4', locality='Кривий Ріг, Покровський', area='49'),
#  Estate(title="Дуже тепла, автономне опалення 2-х кімнатна квартира Кам'янське, Соцмі", price='16 000 $', floor='3', storey='5', locality="Кам'янське", area='43.40'),
#  Estate(title='Сдам дом посуточно 13 км от Харькова', price='1 500 грн.', floor='?', storey='?', locality='Люботин', area='150'),
#  Estate(title='Грушевського93/1', price='44 500 $', floor='3', storey='5', locality='Черкаси', area='45.50'),
#  Estate(title='2к. 44м2. Павлово Поле, м.23 Серпня (23 Августа,ул. Балакирева).114659', price='45 000 $', floor='5', storey='9', locality='Харків, Шевченківський ', area='44'),
#  Estate(title='Продам будинок 145м.кв. в с. Білогородка', price='155 000 $', floor='?', storey='2', locality='Білогородка', area='145'),
#  Estate(title='Продам гараж в центрі біля Старого Кругу', price='12 500 $', floor='?', storey='?', locality='Кропивницький, Подільський', area='25'),
#  Estate(title='1-к студия на пр Поля 94  800 грн/сут  Посуточно почасово', price='800 грн.', floor='4', storey='?', locality='Дніпро, Центральний', area='40'),
#  Estate(title='3к квартира с видом на море в кирпичном доме от хозяина', price='69 000 $', floor='5', storey='8', locality='Чорноморськ', area='110'),
#  Estate(title='Комфорт Таун. Здам 2 к = кухня студія + спальня. Хазяїн! Без комисії!', price='17 000 грн.', floor='3', storey='9', locality='Київ, Дніпровський', area='44'),
#  Estate(title='Жашків.Здам в оренду/продам', price='120 грн.', floor='?', storey='?', locality='Жашків', area='65'),
#  Estate(title='Здам простору квартиру подобово 3 кімнати Ужгород', price='1 200 грн.', floor='3', storey='?', locality='Ужгород', area='90'),
#  Estate(title='(!) Будинок з грубкою ,  по доступній вартості', price='11 000 $', floor='?', storey='1', locality='Оженин', area='52'),
#  Estate(title='Продається 3-кімнатна квартира, вул. Корзо Код: 16186', price='125 000 $', floor='3', storey='3', locality='Ужгород', area='116'),
#  Estate(title='Будинок 800 м2 у Конча-Заспі, КМ "Золоті Ворота"', price='1 450 000 $', floor='?', storey='2', locality='Козин', area='800'),
#  Estate(title='Продам 1 кв на Новых домах', price='18 700 $', floor='3', storey='9', locality='Харків, Слобідський', area='26'),
#  Estate(title='Оренда офіса 1673 м2 Європасаж метро Олімпійська', price='14 $', floor='5', storey='5', locality='Київ, Печерський', area='1'),
#  Estate(title='Аренда квартиры студио Печерск', price='950 $', floor='14', storey='26', locality='Київ, Печерський', area='72'),
#  Estate(title='Елегантна квартира 206 кв.м. з краєвидом на парк Глоби', price='365 000 $', floor='7', storey='10', locality='Дніпро, Центральний', area='207'),
#  Estate(title='Продається ультрасучасна квартира в ЖК Мирний, на пр. Миру, 4Б м1', price='79 500 $', floor='8', storey='9', locality='Миколаїв, Iнгульський', area='63.40'),
#  Estate(title='Квартира студия 5 минут пешком до Арх. Бекетова', price='4 000 грн.', floor='1', storey='2', locality='Степова', area='40'),
#  Estate(title='Чудова однокімнатна квартира від власника.', price='38 000 $', floor='4', storey='9', locality='Чернігів', area='40'),
#  Estate(title='єОселя.Будинок №3 зданий.2 кімнатна квартира в ЖК Бережанський', price='72 500 $', floor='16', storey='25', locality='Київ, Оболонський', area='67'),
#  Estate(title='Продам ділянку в Шкуринцях', price='140 000 $', floor='?', storey='?', locality='Вінниця, Ленінський', area='?'),
#  Estate(title='Продам трикімнатну на Печерську', price='193 000 $', floor='7', storey='13', locality='Київ, Печерський', area='91'),
#  Estate(title='Ділянка під будівництво будинка у Крюкові', price='3 500 $', floor='?', storey='?', locality='Кременчук', area='?'),
#  Estate(title='1 кварт.приват сектор від власника Ірпінь без  комісіі', price='6 500 грн.', floor='1', storey='2', locality='Ірпінь', area='30'),
#  Estate(title='Продам будинок 90м² Ходосовка, 5 км до м. Видубічі', price='80 000 $', floor='?', storey='1', locality='Ходосівка', area='90'),
#  Estate(title='Продам будинок в с. Манченки', price='11 500 $', floor='?', storey='1', locality='Манченки', area='87'),
#  Estate(title='Відпочинок в Карпатах', price='600 грн.', floor='?', storey='?', locality='Ворохта', area='500'),
#  Estate(title='‼️Квартира подобово Трускавець‼️', price='550 грн.', floor='1', storey='?', locality='Трускавець', area='45'),
#  Estate(title='Продажа Парк Ленд, 70кв, 2к, дизайнерский ремонт, ЄОселя, NEW', price='124 990 $', floor='9', storey='10', locality='Київ, Голосіївський', area='70'),
#  Estate(title='Сдам Реальную 3-х комн кв, Победа, р-н МсDonalds  и 5й Континента', price='14 000 грн.', floor='2', storey='9', locality='Дніпро, Соборний', area='72'),
#  Estate(title='Оренда подобова 1 кім квартири в Ужгороді', price='650 грн.', floor='5', storey='?', locality='Ужгород', area='35'),
#  Estate(title='4х-комнатная квартира, S=108 м2, Центр, Пушкинская. ЖБ.', price='82 000 $', floor='3', storey='4', locality='Харків, Київський', area='108'),
#  Estate(title='Кімната для хлопця або дівчини метро Харківська без комісії без господ', price='2 499 грн.', floor='2', storey='16', locality='Київ, Дарницький', area='80'),
#  Estate(title='Сдам квартиру посуточно  Покровск', price='1 200 грн.', floor='4', storey='?', locality='Покровськ', area='45'),
#  Estate(title='Будинок у селі Сенча Миргородського району Полтавської області', price='11 000 $', floor='?', storey='1', locality='Сенча', area='115'),
#  Estate(title='Квартира Люкс зі СМАРТ ТВ ЖК «Туркіш сіті» проспект Коцюбинського', price='1 100 грн.', floor='3', storey='?', locality='Вінниця, Замостянський', area='46'),
#  Estate(title='Метро Пушкинская, Университет на 4 человека', price='490 грн.', floor='5', storey='?', locality='Харків, Київський', area='28'),
#  Estate(title='Зарічний, Школа міліціі, тільки під ваш ремонт', price='14 800 $', floor='8', storey='9', locality='Кривий Ріг, Покровський', area='57'),
#  Estate(title='Продаж. 3 Східний, 4 поверх, під ремонт, 18700. Обмін на 1 кім.', price='18 700 $', floor='4', storey='9', locality='Кривий Ріг, Долгинцевський', area='70'),
#  Estate(title='Продаж однокімнатної квартири в «Orange City»', price='54 000 $', floor='8', storey='27', locality='Київ, Голосіївський', area='49.90'),
#  Estate(title='Аркадия, ЖК на Каманина, отдельная спальня, новая!', price='700 грн.', floor='10', storey='?', locality='Одеса, Приморський', area='45'),
#  Estate(title='1 комнатная квартира в ипотеку! еОселя! Застройщик, 2% оформление', price='33 120 $', floor='5', storey='5', locality='Ірпінь', area='36.80'),
#  Estate(title='2 кімнатна з ремонтом, м. Ірпінь, Центральний парк', price='67 000 $', floor='9', storey='10', locality='Ірпінь', area='56'),
#  Estate(title='Продам коттедж в с. Ясіня Карпатах гора Драгобрат Буковель', price='68 000 $', floor='?', storey='2', locality='Лазещина', area='120'),
#  Estate(title='Продаж 3-х кімнатної квартири вул. Старонаводницька 6Б, Печерськ', price='270 000 $', floor='8', storey='25', locality='Київ, Печерський', area='128'),
#  Estate(title='Продам 2-к комнатную квартиру. Проспект Юбилейный 61.', price='39 000 $', floor='7', storey='9', locality='Харків, Салтівський', area='65'),
#  Estate(title='Посуточно 2ком-я в центре Киева(ТЦ"Gulliver")на бул.Леси Украинки 3', price='1 000 грн.', floor='7', storey='?', locality='Київ, Печерський', area='55'),
#  Estate(title='Земля Гостомель ділянка земельна 26,5 соток', price='1 700 $', floor='?', storey='?', locality='Гостомель', area='?'),
#  Estate(title='Продам двухкомнатную квартиру. Левый берег Каменского', price='22 600 $', floor='7', storey='9', locality="Кам'янське", area='49'),
#  Estate(title='Будинок 35 км від м.Луцьк', price='6 000 $', floor='?', storey='1', locality='Полонка', area='32.50'),
#  Estate(title='Квартиры посуточно от 700 грн до 1300грн', price='700 грн.', floor='2', storey='?', locality='Краматорськ', area='42'),
#  Estate(title='500 м.кв. Метро Золотые ворота. Софиевская площадь', price='17 $', floor='2', storey='?', locality='Київ, Шевченківський', area='500'),
#  Estate(title='Без Комиссии! ЖК Новый берег.Фонтан.Литературная .Долгосрочно', price='900 $', floor='19', storey='25', locality='Одеса, Приморський', area='100'),
#  Estate(title='Здам в оренду складські приміщення від 20 кв.м. до 900 кв.м.', price='50 грн.', floor='?', storey='?', locality='Суми', area='900'),
#  Estate(title='Продам дом район Черевковка', price='582 000 грн.', floor='?', storey='1', locality="Слов'янськ", area='80'),
#  Estate(title='Уютная квартира прямо возле метро "Пушкинская"', price='400 грн.', floor='3', storey='?', locality='Харків, Київський', area='30'),
#  Estate(title='Територія Ділянка Нерухомість Приміщення Максимівка Збаразький р-н', price='100 $', floor='?', storey='?', locality='Максимівка', area='8'),
#  Estate(title='Общежитие в Киеве Мы работаем ! Метро Тараса Шевченко Подол Хостел', price='90 грн.', floor='?', storey='?', locality='Київ, Подільський', area='?'),
#  Estate(title='Цена Снижена!  Продам Видовую 2кв  метро Студенческая, Рядом Родник.', price='27 500 $', floor='7', storey='16', locality='Харків, Салтівський', area='52'),
#  Estate(title='1-кім.кв вул. Мельника, новобудова', price='300 $', floor='9', storey='10', locality='Івано-Франківськ', area='42'),
#  Estate(title='Голосіївський р-н, вул. Метрологічна 21Б, ЖК Кришталеві джерела', price='83 000 $', floor='5', storey='8', locality='Київ, Голосіївський', area='67'),
#  Estate(title='Ірпінь!!! Оренда робочих місць!!! Центр!!!', price='167 грн.', floor='1', storey='?', locality='Ірпінь', area='40'),
#  Estate(title='Земля під забудову', price='5 500 $', floor='?', storey='?', locality='Піщане', area='?'),
#  Estate(title='АКЦІЯ.ОРЕНДА комер. прим.площею від 80м.кв. (містечко "Соборне").', price='200 грн.', floor='1', storey='10', locality='Івано-Франківськ', area='1'),
#  Estate(title='2к квартира 83 м  по пер Балтийский, 5 ЖК Навигатор Є Оселя', price='74 000 $', floor='21', storey='25', locality='Київ, Оболонський', area='83'),
#  Estate(title='Продам 1 ком. квартиру ул. Космонавтов 3 в хорошем состоянии.', price='23 000 $', floor='1', storey='5', locality='Харків, Шевченківський ', area='31'),
#  Estate(title='Здам 1но кім Грюндвальська', price='11 000 грн.', floor='3', storey='3', locality='Львів, Залізничний', area='34'),
#  Estate(title='Оренда нежитлового приміщення Святопетрівське', price='9 000 грн.', floor='?', storey='?', locality='Київ, Святошинський', area='22'),
#  Estate(title='Квартира 1-комнатная посуточно в центре', price='1 000 грн.', floor='7', storey='?', locality="Слов'янськ", area='36'),
#  Estate(title='Продаж від власника! 2 кімнатна квартира', price='65 000 $', floor='6', storey='10', locality='Дніпро, Центральний', area='55'),
#  Estate(title='Продажа/обмен/ Трёхкомнатная квартира от собственника.', price='27 000 $', floor='5', storey='5', locality='Кременчук', area='48'),
#  Estate(title='Продажа Будинок с.Мала Туря', price='60 000 $', floor='?', storey='2', locality='Долина', area='100'),
#  Estate(title='Продам гараж під бус(трафік,віто)', price='2 100 $', floor='?', storey='?', locality='Годилів', area='21'),
#  Estate(title='здам квартиру подобово в центрі м. Ужгород панорамне небо', price='600 грн.', floor='3', storey='?', locality='Ужгород', area='20'),
#  Estate(title='Продам 1к. квартиру. Виноградарь.. ул.Краснопольская 1а. Кирпичный дом', price='33 000 $', floor='9', storey='9', locality='Київ, Подільський', area='34'),
#  Estate(title='Сучасна квартира з трьох кімнат. Мебльована і з технікою.', price='16 800 $', floor='5', storey='5', locality='Кривий Ріг, Покровський', area='56'),
#  Estate(title='ЦЕНТР 1-кім квартира. вул Руська + Звітні документи', price='750 грн.', floor='4', storey='?', locality='Тернопіль', area='35'),
#  Estate(title='Аппартаменты VIP жк Металлист посуточно, почасово', price='1 100 грн.', floor='4', storey='?', locality='Харків, Слобідський', area='40'),
#  Estate(title='Продаж квартири ЖК «Авіатор» 39м2', price='29 990 $', floor='7', storey='10', locality='Чернігів', area='38'),
#  Estate(title='Комфорт і затишок,Продаж Квартири, Є Оселя Чабани', price='60 000 $', floor='8', storey='10', locality='Чабани', area='46'),
#  ...]

# %% [markdown]
# # writing estates to google sheet

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials


def connection() -> gspread:
    creds = ServiceAccountCredentials.from_json_keyfile_name("keys.json")
    file = gspread.authorize(creds)
    workbook = file.open("Parse_estates")
    sheet = workbook.sheet1
    return sheet


def write_to_google_sheet(data: [Estate]):
    sheet = connection()
    sheet.clear()

    header_row = PRODUCT_FIELDS
    sheet.append_row(header_row)

    rows_to_insert = [[getattr(estate, field) for field in header_row] for estate in data]
    sheet.insert_rows(rows_to_insert, row=2)

write_to_google_sheet(soup_estates_info)
